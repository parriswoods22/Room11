# %%
# Dependencies
import requests
import json
from pprint import pprint
# Retrieve Google API key from config.py
from config import gkey

# %%
# What are the geocoordinates (latitude/longitude) of The Bronx, New York
target_city = "The Bronx, New York"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of The Bronx, NY")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# # Convert to JSON
bronx_geo = response.json()

# Extract lat/lng
lat = bronx_geo["results"][0]["geometry"]["location"]["lat"]
lng = bronx_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
# print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of The Bronx, NY
# https://maps.googleapis.com/maps/api/geocode/json?address=The+Bronx%2C+New+York&key=AIzaSyDZjSshWKAc5jfzqIeHa84Lyt8alt8wrV0

# %%
# Find the name and address of a tourist attraction in The Bronx, New York.
target_type = "tourist_attraction"
bronx_coords = "40.8447819, -73.8648268"
radius = 8000

# rewrite params dict

params = {
    "location": bronx_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Tourist Attraction in The Bronx, NY")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

bronx_att = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(bronx_att, indent=4, sort_keys=True))

#extract lng and lat of attraction
lat = brooklyn_att["results"][0]["geometry"]["location"]["lat"]
lng = brooklyn_att["results"][0]["geometry"]["location"]["lng"]

# Print the name and address of the first attraction to appear
# print(bronx_att["results"][0]["name"])
# print(bronx_att["results"][0]["vicinity"])
# print(f"Location: {lat}, {lng}")

# %%
# What are the geocoordinates (latitude/longitude) of The Brooklyn, New York
target_city = "Brooklyn, New York"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of The Brooklyn, NY")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
brooklyn_geo = response.json()

# Extract lat/lng
lat = brooklyn_geo["results"][0]["geometry"]["location"]["lat"]
lng = brooklyn_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
# print(f"{target_city}: {lat}, {lng}")

# %%
#Find the name and address of a tourist attraction in The Brooklyn, New York.
target_type = "tourist_attraction"
brooklyn_coords = "40.6781784, -73.9441579"
radius = 8000

# rewrite params dict

params = {
    "location": brooklyn_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Tourist Attraction in The Brooklyn, NY")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

brooklyn_att = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(brooklyn_att, indent=4, sort_keys=True))

#extract lng and lat of attraction
lat = brooklyn_att["results"][0]["geometry"]["location"]["lat"]
lng = brooklyn_att["results"][0]["geometry"]["location"]["lng"]

# Print the name and address of the first attraction to appear
# print(brooklyn_att["results"][0]["name"])
# print(brooklyn_att["results"][0]["vicinity"])
# print(f"Location: {lat}, {lng}")

# %%
# Find the name and address of a tourist attraction in The Manhattan, New York.
target_city = "Manhattan, New York"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of The Brooklyn, NY")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
manhattan_geo = response.json()

# Extract lat/lng
lat = manhattan_geo["results"][0]["geometry"]["location"]["lat"]
lng = manhattan_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
# print(f"{target_city}: {lat}, {lng}")

# %%
#Find the name and address of a tourist attraction in The Manhattan, New York.
target_type = "tourist_attraction"
manhattan_coords = "40.7830603, -73.9712488"
radius = 8000

# rewrite params dict

params = {
    "location": manhattan_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Tourist Attraction in The Brooklyn, NY")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

manhattan_att = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(manhattan_att, indent=4, sort_keys=True))

#extract lng and lat of attraction
lat = manhattan_att["results"][0]["geometry"]["location"]["lat"]
lng = manhattan_att["results"][0]["geometry"]["location"]["lng"]

# Print the name and address of the first attraction to appear
# print(manhattan_att["results"][0]["name"])
# print(manhattan_att["results"][0]["vicinity"])
# print(f"Location: {lat}, {lng}")
