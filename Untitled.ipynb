# %%
import pandas as pd

# %%
data_one_path = 'Resources/airbnbmark1.csv'
data_two_path = 'Resources/AB_NYC_2019.csv'
data_one = pd.read_csv(data_one_path)
data_two = pd.read_csv(data_two_path)
# Out:
# C:\Users\Charles Hilgeman\anaconda\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_one.head(1)
# Out:
#      id                   name  \
# 0  2595  Skylit Midtown Castle
#
#                                              summary  host_id  \
# 0  Beautiful, spacious skylit studio in the heart...     2845
#
#   host_response_rate host_acceptance_rate host_is_superhost neighbourhood  \
# 0                50%                  38%                 f       Midtown
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  ... availability_365  \
# 0                Midtown                    Manhattan  ...              365
#
#    number_of_reviews  review_scores_rating review_scores_accuracy  \
# 0                 48                  94.0                    9.0
#
#   review_scores_cleanliness  review_scores_checkin  \
# 0                       9.0                   10.0
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        10.0                   10.0                 9.0
#
#   reviews_per_month
# 0              0.39
#
# [1 rows x 30 columns]

# %%
ident = data_one['id']
name = data_one['name']
rpm = data_one['reviews_per_month']
peoples = data_one['accommodates']
cleaning = data_one['cleaning_fee']
avg_rating = data_one['review_scores_rating']
accuracy = data_one['review_scores_rating']
cleanliness = data_one['review_scores_rating']
checkin = data_one['review_scores_checkin']
comm = data_one['review_scores_communication']
location = data_one['review_scores_location']
value = data_one['review_scores_value']

basic_info_df = pd.DataFrame({'ID': ident,
                             'Room Name': name,
                              'Accomodates': peoples,
                              'Cleaning Fee': cleaning,
                             'Reviews Per Month': rpm,
                             'Rating Score': avg_rating,
                             'Accuracy Score': accuracy,
                             'Cleanliness': cleanliness,
                             'Checkin Score': checkin,
                             'Communication Score': comm,
                             'Location Score': location,
                             'Value Score': value})
basic_info_df.head(2)
# Out:
#      ID                        Room Name  Accomodates Cleaning Fee  \
# 0  2595            Skylit Midtown Castle            1      $95.00
# 1  3831  Cozy Entire Floor of Brownstone            3          NaN
#
#    Reviews Per Month  Rating Score  Accuracy Score  Cleanliness  \
# 0               0.39          94.0            94.0         94.0
# 1               4.69          90.0            90.0         90.0
#
#    Checkin Score  Communication Score  Location Score  Value Score
# 0           10.0                 10.0            10.0          9.0
# 1           10.0                  9.0            10.0          9.0

# %%
ident2 = data_two['id']
host_id = data_two['host_id']
borough = data_two['neighbourhood_group']
neighborhood = data_two['neighbourhood']
lat = data_two['latitude']
lng = data_two['longitude']
room_type = data_two['room_type']
price = data_two['price']
review_num = data_two['number_of_reviews']
avail = data_two['availability_365']

# %%
basic_two_df = pd.DataFrame({'ID': ident2,
                            'Host ID': host_id,
                            'Borough': borough,
                            'Neighbourhood': neighborhood,
                            'Latitude': lat,
                            'Longitude': lng,
                            'Type Room': room_type,
                            'Price (per night)': price,
                            'Number of Reviews': review_num,
                            'Availability per 365': avail})
basic_two_df
# Out:
#              ID   Host ID    Borough       Neighbourhood  Latitude  Longitude  \
# 0          2539      2787   Brooklyn          Kensington  40.64749  -73.97237
# 1          2595      2845  Manhattan             Midtown  40.75362  -73.98377
# 2          3647      4632  Manhattan              Harlem  40.80902  -73.94190
# 3          3831      4869   Brooklyn        Clinton Hill  40.68514  -73.95976
# 4          5022      7192  Manhattan         East Harlem  40.79851  -73.94399
# ...         ...       ...        ...                 ...       ...        ...
# 48890  36484665   8232441   Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891  36485057   6570630   Brooklyn            Bushwick  40.70184  -73.93317
# 48892  36485431  23492952  Manhattan              Harlem  40.81475  -73.94867
# 48893  36485609  30985759  Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894  36487245  68119814  Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              Type Room  Price (per night)  Number of Reviews  \
# 0         Private room                149                  9
# 1      Entire home/apt                225                 45
# 2         Private room                150                  0
# 3      Entire home/apt                 89                270
# 4      Entire home/apt                 80                  9
# ...                ...                ...                ...
# 48890     Private room                 70                  0
# 48891     Private room                 40                  0
# 48892  Entire home/apt                115                  0
# 48893      Shared room                 55                  0
# 48894     Private room                 90                  0
#
#        Availability per 365
# 0                       365
# 1                       355
# 2                       365
# 3                       194
# 4                         0
# ...                     ...
# 48890                     9
# 48891                    36
# 48892                    27
# 48893                     2
# 48894                    23
#
# [48895 rows x 10 columns]

# %%
combined_data = pd.merge(basic_info_df, basic_two_df, on = 'ID')
cleaned_data = combined_data.dropna(how = 'any')
cleaned_data
# Out:
#               ID                                          Room Name  \
# 0           2595                              Skylit Midtown Castle
# 1           2595                              Skylit Midtown Castle
# 2           2595                              Skylit Midtown Castle
# 6           5099          Large Cozy 1 BR Apartment In Midtown East
# 7           5099          Large Cozy 1 BR Apartment In Midtown East
# ...          ...                                                ...
# 113091  35596905     CONEY ISLAND BEACH close to Manhattan New York
# 113092  35706482                      Trendy Williamsburg Apartment
# 113093  35948011  Classic,  Urban with a splash of Glam!  Near M...
# 113094  36176586  BRAND NEW KING 2br Airports& Times Sq MINUTES ...
# 113096  36372006           [F] Quiet Cozy Room Near Subway Station.
#
#         Accomodates Cleaning Fee  Reviews Per Month  Rating Score  \
# 0                 1      $95.00                0.39          94.0
# 1                 1      $95.00                0.39          94.0
# 2                 2      $95.00                0.38          94.0
# 6                 2     $125.00                0.59          90.0
# 7                 2     $125.00                0.60          90.0
# ...             ...          ...                ...           ...
# 113091            4     $100.00                0.28         100.0
# 113092            2      $50.00                0.13         100.0
# 113093            3     $119.00                2.42          97.0
# 113094           10      $80.00                2.50          85.0
# 113096            2      $25.00                1.53         100.0
#
#         Accuracy Score  Cleanliness  Checkin Score  Communication Score  ...  \
# 0                 94.0         94.0           10.0                 10.0  ...
# 1                 94.0         94.0           10.0                 10.0  ...
# 2                 94.0         94.0           10.0                 10.0  ...
# 6                 90.0         90.0           10.0                 10.0  ...
# 7                 90.0         90.0           10.0                 10.0  ...
# ...                ...          ...            ...                  ...  ...
# 113091           100.0        100.0           10.0                 10.0  ...
# 113092           100.0        100.0           10.0                 10.0  ...
# 113093            97.0         97.0           10.0                 10.0  ...
# 113094            85.0         85.0            9.0                  8.0  ...
# 113096           100.0        100.0           10.0                 10.0  ...
#
#         Value Score    Host ID    Borough Neighbourhood  Latitude  Longitude  \
# 0               9.0       2845  Manhattan       Midtown  40.75362  -73.98377
# 1               9.0       2845  Manhattan       Midtown  40.75362  -73.98377
# 2               9.0       2845  Manhattan       Midtown  40.75362  -73.98377
# 6               9.0       7322  Manhattan   Murray Hill  40.74767  -73.97500
# 7               9.0       7322  Manhattan   Murray Hill  40.74767  -73.97500
# ...             ...        ...        ...           ...       ...        ...
# 113091         10.0   29622548   Brooklyn  Coney Island  40.58101  -73.98514
# 113092         10.0   16342788   Brooklyn  Williamsburg  40.70690  -73.94521
# 113093         10.0  269165235  Manhattan  East Village  40.72546  -73.98703
# 113094          9.0  272080566     Queens      Elmhurst  40.73480  -73.86906
# 113096         10.0  118405437     Queens     Woodhaven  40.69411  -73.86877
#
#               Type Room Price (per night)  Number of Reviews  \
# 0       Entire home/apt               225                 45
# 1       Entire home/apt               225                 45
# 2       Entire home/apt               225                 45
# 6       Entire home/apt               200                 74
# 7       Entire home/apt               200                 74
# ...                 ...               ...                ...
# 113091  Entire home/apt               149                  0
# 113092     Private room                79                  0
# 113093  Entire home/apt               235                  1
# 113094  Entire home/apt               199                  0
# 113096     Private room                66                  0
#
#         Availability per 365
# 0                        355
# 1                        355
# 2                        355
# 6                        129
# 7                        129
# ...                      ...
# 113091                   297
# 113092                   342
# 113093                   326
# 113094                   157
# 113096                   365
#
# [78307 rows x 21 columns]

# %%
cleaned_data.to_csv('Resources/cleaned_data.csv')
